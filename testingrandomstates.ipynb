# %%
import random

# %%
random_list = [random.random() for x in range(10)]
random_list
# Out:
# [0.6536479756400722,
#  0.95652941121791,
#  0.34763316132825484,
#  0.42834590922932625,
#  0.08831022129645694,
#  0.6433883874065627,
#  0.11078925164995113,
#  0.10646822754366003,
#  0.2407597902142744,
#  0.9368676210870059]

# %% [markdown]
# [0.6536479756400722,
#  0.95652941121791,
#  0.34763316132825484,
#  0.42834590922932625,
#  0.08831022129645694,
#  0.6433883874065627,
#  0.11078925164995113,
#  0.10646822754366003,
#  0.2407597902142744,
#  0.9368676210870059]

# %%
random.random()
# Out:
# 0.763774618976614

# %%
# Out:
# (3,
#  (2147483648,
#   3564348608,
#   1266698288,
#   4212342371,
#   3595291661,
#   3180588708,
#   3037210256,
#   946923017,
#   2565409715,
#   2900535780,
#   924383152,
#   4180157270,
#   4230508198,
#   2039675917,
#   3755350407,
#   2362848650,
#   2818100609,
#   2097423432,
#   524478045,
#   540883378,
#   281170210,
#   1485176884,
#   1493190386,
#   1773214509,
#   380915208,
#   3667698522,
#   2648371337,
#   2961234806,
#   3857480267,
#   1582950522,
#   246289694,
#   3322185604,
#   1944574775,
#   302623699,
#   169865066,
#   1143540808,
#   3733177770,
#   513116636,
#   1411153081,
#   3205493053,
#   768926902,
#   549624109,
#   1470655403,
#   59539609,
#   3678480009,
#   3087139671,
#   1176835859,
#   2078491503,
#   2299934332,
#   1592059249,
#   1062716176,
#   2654193596,
#   3531838733,
#   2661260596,
#   3881209635,
#   2106865768,
#   4154287292,
#   2082185616,
#   2301197011,
#   2177349827,
#   3082181756,
#   1787663536,
#   3714670796,
# ...
